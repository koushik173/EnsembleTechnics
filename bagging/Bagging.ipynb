# %%
## importing models
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB 
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import BaggingClassifier

import pandas as  pd

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # dataSet handle

# %%
df = pd.read_csv("Heart.csv")
df[['Thal', 'ChestPain', 'AHD']] = df[['Thal', 'ChestPain', 'AHD']].apply(lambda x: pd.factorize(x)[0])
df.rename(columns =  {'AHD': "target"}, inplace = True)
df.dropna(inplace=True)
X=df.iloc[:,1:14]
y = df.iloc[:,14]
X_train,X_test,y_train, y_test = train_test_split( X,y,test_size=.25,random_state=42)

# %% [markdown]
# # different model prediction

# %%
logReg = LogisticRegression()
randmFst = RandomForestClassifier()
svcClf = SVC()
nbGclf = GaussianNB()

# %%
for clf in (logReg, randmFst, svcClf, nbGclf):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(clf.__class__.__name__, accuracy_score(y_test, y_pred))
# Out:
# LogisticRegression 0.84
# RandomForestClassifier 0.8533333333333334
# SVC 0.6533333333333333
# GaussianNB 0.7733333333333333

# %% [markdown]
# # Bagging with GaussianNB (naive bayes)

# %%
X_train,X_test,y_train, y_test = train_test_split( X,y,test_size=.25,random_state=4)

# %%
bag_nb_clf = BaggingClassifier(GaussianNB(), n_estimators=500, max_samples=100, bootstrap = True,
                              n_jobs = -1, oob_score=False, max_features=0.7)
bag_nb_clf.fit(X_train, y_train)

print("Accuracy of train data: ", bag_nb_clf.score(X_train, y_train))
y_pred = bag_nb_clf.predict(X_test)
print("Accuracy of test data: ",accuracy_score(y_test, y_pred))
#bag_nb_clf.oob_score_
# Out:
# Accuracy of train data:  0.8258928571428571
# Accuracy of test data:  0.8533333333333334

# %% [markdown]
# # Bagging with Logistics Regression

# %%
bag_nb_clf = BaggingClassifier(logReg, n_estimators=500, max_samples=100, bootstrap = True,
                              n_jobs = -1, oob_score=True, max_features=0.7)
bag_nb_clf.fit(X_train, y_train)

print("Accuracy of train data: ", bag_nb_clf.score(X_train, y_train))
y_pred = bag_nb_clf.predict(X_test)
print("Accuracy of test data: ",accuracy_score(y_test, y_pred))
bag_nb_clf.oob_score_
# Out:
# /home/koushik/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/koushik/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# # bagging with SVC

# %%
bag_nb_clf = BaggingClassifier(svcClf, n_estimators=500, max_samples=100, bootstrap = True,
                              n_jobs = -1, oob_score=True, max_features=0.7)
bag_nb_clf.fit(X_train, y_train)

print("Accuracy of train data: ", bag_nb_clf.score(X_train, y_train))
y_pred = bag_nb_clf.predict(X_test)
print("Accuracy of test data: ",accuracy_score(y_test, y_pred))
bag_nb_clf.oob_score_
# Out:
# Accuracy of train data:  0.6205357142857143
# Accuracy of test data:  0.56
# 0.6026785714285714

# %% [markdown]
# # Random Forest
# by default bagging

# %%
bag_nb_clf = RandomForestClassifier(n_estimators=500, max_samples=100, bootstrap = True,
                              n_jobs = -1, oob_score=True, max_features=0.7, max_depth= 6)
bag_nb_clf.fit(X_train, y_train)

print("Accuracy of train data: ", bag_nb_clf.score(X_train, y_train))
y_pred = bag_nb_clf.predict(X_test)
print("Accuracy of test data: ",accuracy_score(y_test, y_pred))
bag_nb_clf.oob_score_
# Out:
# Accuracy of train data:  0.9553571428571429
# Accuracy of test data:  0.8133333333333334
# 0.7901785714285714

# %% [markdown]
# # bagging with DecisionTree

# %%
bag_nb_clf = BaggingClassifier(DecisionTreeClassifier(), n_estimators=500, max_samples=100, bootstrap = True,
                              n_jobs = -1, oob_score=True, max_features=0.7)
bag_nb_clf.fit(X_train, y_train)

print("Accuracy of train data: ", bag_nb_clf.score(X_train, y_train))
y_pred = bag_nb_clf.predict(X_test)
print("Accuracy of test data: ",accuracy_score(y_test, y_pred))
bag_nb_clf.oob_score_
# Out:
# Accuracy of train data:  0.9821428571428571
# Accuracy of test data:  0.8133333333333334
# 0.7991071428571429

# %%
logReg = LogisticRegression()
randmFst = RandomForestClassifier()
svcClf = SVC()
nbGclf = GaussianNB()
dtClf = DecisionTreeClassifier()
liss = [randmFst, svcClf, nbGclf, dtClf,logReg]

# %%
for model in liss:
    bag_nb_clf = BaggingClassifier(model, n_estimators=500, max_samples=100, bootstrap = True,
                              n_jobs = -1, oob_score=True, max_features=0.7)
    bag_nb_clf.fit(X_train, y_train)

    print("Accuracy of ",model.__class__.__name__ + " train data:", bag_nb_clf.score(X_train, y_train))
    y_pred = bag_nb_clf.predict(X_test)
    print("Accuracy of ",model.__class__.__name__ + " test data: ",accuracy_score(y_test, y_pred))

    #bag_nb_clf.oob_score_
    print("Accuracy with oob of",model.__class__.__name__ + " data: ",bag_nb_clf.oob_score_)
    print("\n")
# Out:
# Accuracy of  RandomForestClassifier train data: 0.9419642857142857
# Accuracy of  RandomForestClassifier test data:  0.84
# Accuracy with oob of RandomForestClassifier data:  0.8125
#
#
# Accuracy of  SVC train data: 0.6116071428571429
# Accuracy of  SVC test data:  0.5466666666666666
# Accuracy with oob of SVC data:  0.5892857142857143
#
#
# Accuracy of  GaussianNB train data: 8.214285714285714e-01
# Accuracy of  GaussianNB test data:  0.8533333333333334
# Accuracy with oob of GaussianNB data:  0.8080357142857143
#
#
# Accuracy of  DecisionTreeClassifier train data: 0.9776785714285714
# Accuracy of  DecisionTreeClassifier test data:  0.8266666666666667
# Accuracy with oob of DecisionTreeClassifier data:  0.7946428571428571
# /home/koushik/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...
